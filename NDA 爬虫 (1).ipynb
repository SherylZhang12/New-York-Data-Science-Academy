# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [raw]
# import pandas as pd
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# import time
# from selenium.webdriver.chrome.service import Service
#
# # ✅ 80家公司列表（按金融、医疗、科技顺序）
# companies = [
#     # 金融（前27）
#     "JPMorgan Chase & Co.", "Goldman Sachs", "Morgan Stanley", "Bank of America", "Citigroup",
#     "BlackRock", "Fidelity Investments", "Prudential Financial", "The Hartford", "Bloomberg L.P.",
#     "American Express", "Mastercard", "Moody's Corporation", "S&P Global", "BNY Mellon",
#     "State Street Corporation", "Travelers", "Chubb", "Marsh McLennan", "AIG",
#     "Capital One", "TD Bank Group", "UBS", "Barclays", "Deutsche Bank", "Macquarie Group", "AllianceBernstein",
#
#     # 医疗（中27）
#     "Johnson & Johnson", "Pfizer", "Merck", "Bristol Myers Squibb", "CVS Health",
#     "Cigna", "Boston Scientific", "Stryker Corporation", "Becton, Dickinson and Company (BD)",
#     "Regeneron Pharmaceuticals", "Vertex Pharmaceuticals", "Moderna", "IQVIA", "Quest Diagnostics",
#     "Hologic", "Mount Sinai Health System", "NewYork-Presbyterian Hospital", "Northwell Health",
#     "Mass General Brigham", "Dana-Farber Cancer Institute", "UnitedHealth Group", "Anthem (Elevance Health)",
#     "Zoetis", "Biogen", "Gilead Sciences", "Eli Lilly and Company", "Teva Pharmaceutical Industries",
#
#     # IT/科技（后26）
#     "IBM", "Verizon", "Oracle", "Dell Technologies", "SAP", "Cisco Systems", "Adobe", "Salesforce",
#     "Microsoft", "Amazon", "Google", "Meta Platforms", "Comcast", "Cognizant", "Automatic Data Processing (ADP)",
#     "NVIDIA", "Corning Incorporated", "Thomson Reuters", "Dassault Systèmes", "PTC",
#     "Akamai Technologies", "Red Hat", "Wayfair", "Tripadvisor", "Gartner", "ServiceNow"
# ]
#
# # ✅ 搜索关键词（统一设为数据科学相关负责人）
# keywords = ["Head of Data Science / CTO / VP of Innovation"] * len(companies)
#
# results = []
#
# # ✅ Chrome 配置
# options = webdriver.ChromeOptions()
# # options.add_argument("--headless")  # 运行时可取消注释以显示浏览器
# options.add_argument("--disable-gpu")
# options.add_argument("--disable-blink-features=AutomationControlled")
# options.add_argument("--log-level=3")
#
# # ✅ 修改为你自己电脑上 ChromeDriver 的路径
# service = Service("/Users/mac/Downloads/chromedriver-mac-x64/chromedriver")
# driver = webdriver.Chrome(service=service, options=options)
#
#
# # ✅ 开始搜索
# for company, keyword in zip(companies, keywords):
#     query = f"{keyword} {company} site:linkedin.com/in"
#     url = f"https://www.bing.com/search?q={query.replace(' ', '+')}"
#
#     print(f"🔍 正在搜索：{company}")
#     driver.get(url)
#     time.sleep(2)
#
#     found_link = "❌ Not Found"
#
#     try:
#         links = driver.find_elements(By.CSS_SELECTOR, 'li.b_algo h2 a')
#         for link in links:
#             href = link.get_attribute("href")
#             if href and "linkedin.com/in" in href:
#                 found_link = href
#                 break
#     except Exception as e:
#         print(f"❌ 错误：{e}")
#         found_link = "❌ Error"
#
#     results.append({
#         "Company Name": company,
#         "Search Keyword": keyword,
#         "LinkedIn Profile": found_link
#     })
#
#     time.sleep(1.5)  # 防止访问太快被封
#
# driver.quit()
#
# # ✅ 输出结果到Excel
# df_result = pd.DataFrame(results)
# df_result.to_excel("NDA_80_Company_Contact_Results_Bing.xlsx", index=False)
#
# print("✅ 全部完成！联系人链接已保存到 NDA_80_Company_Contact_Results_Bing.xlsx")

# %%
df = pd.read_excel("NDA_80_Company_Contact_Results_Bing.xlsx")
df
# Out:
#             Company Name                                 Search Keyword  \
# 0   JPMorgan Chase & Co.  Head of Data Science / CTO / VP of Innovation
# 1          Goldman Sachs  Head of Data Science / CTO / VP of Innovation
# 2         Morgan Stanley  Head of Data Science / CTO / VP of Innovation
# 3        Bank of America  Head of Data Science / CTO / VP of Innovation
# 4              Citigroup  Head of Data Science / CTO / VP of Innovation
# ..                   ...                                            ...
# 75               Red Hat  Head of Data Science / CTO / VP of Innovation
# 76               Wayfair  Head of Data Science / CTO / VP of Innovation
# 77           Tripadvisor  Head of Data Science / CTO / VP of Innovation
# 78               Gartner  Head of Data Science / CTO / VP of Innovation
# 79            ServiceNow  Head of Data Science / CTO / VP of Innovation
#
#                                      LinkedIn Profile
# ...
